# %%
import numpy as np
import pandas as pd

# %%
# P1 T0
data_frame = pd.read_html("https://uk.wikipedia.org/wiki/%D0%9D%D0%B0%D1%81%D0%B5%D0%BB%D0%B5%D0%BD%D0%BD%D1%8F_%D0%A3%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D0%B8",
                       attrs={"class": "wikitable collapsible collapsed", "style": "text-align: right"},
                       match="Регіон"
                      )
table = data_frame[0]
table
# Out:
#                Регіон   1950   1960   1970  1990  2000  2012 2014 2019
# 0                Крим  230.0  206.0  160.0   130    73   126    —    —
# 1           Вінницька  224.0  192.0  142.0   124    84   112  109   76
# 2           Волинська  247.0  250.0  179.0   153   112   148  141  101
# 3    Дніпропетровська  204.0  204.0  151.0   123    71   112  111   71
# 4            Донецька  271.0  214.0  140.0   109    61    98   82    —
# 5         Житомирська  261.0  223.0  159.0   129    89   122  120   79
# 6        Закарпатська  314.0  273.0  207.0   168   115   151  146  104
# 7          Запорізька  219.0  197.0  150.0   124    71   106  106   68
# 8   Івано-Франківська  243.0  248.0  182.0   155   103   124  122   88
# 9            Київська  204.0  189.0  156.0   123    73   122  121   80
# 10     Кіровоградська  216.0  171.0  145.0   126    79   110  108   68
# 11          Луганська  262.0  235.0  144.0   116    62    96   51    —
# 12          Львівська  234.0  240.0  171.0   140    91   119  119   87
# 13       Миколаївська  211.0  194.0  155.0   137    80   115  112   71
# 14            Одеська  241.0  192.0  148.0   126    80   127  123   88
# 15         Полтавська  186.0  163.0  131.0   118    70    99  100   65
# 16         Рівненська  269.0  267.0  193.0   158   118   159  148  107
# 17            Сумська  216.0  184.0  132.0   115    70    97   92   60
# 18      Тернопільська  213.0  216.0  157.0   142    92   113  109   76
# 19         Харківська  197.0  173.0  140.0   114    68    99  101   68
# 20         Херсонська  208.0  214.0  166.0   143    85   117  115   81
# 21        Хмельницька  234.0  198.0  148.0   129    85   113  112   79
# 22          Черкаська  205.0  179.0  144.0   123    75   100   98   64
# 23        Чернівецька  247.0  218.0  170.0   148   101   128  129   92
# 24       Чернігівська  220.0  183.0  127.0   108    69    94   90   61
# 25               Київ    NaN  174.0  159.0   120    73   120  121  110
# 26        Севастополь    NaN    NaN    NaN   125    70   120    —    —
# 27            Україна  228.0  205.0  152.0   126    78   114  111   81

# %%
# P1 T1
table.head() # default 5
# Out:
#              Регіон   1950   1960   1970  1990  2000  2012 2014 2019
# 0              Крим  230.0  206.0  160.0   130    73   126    —    —
# 1         Вінницька  224.0  192.0  142.0   124    84   112  109   76
# 2         Волинська  247.0  250.0  179.0   153   112   148  141  101
# 3  Дніпропетровська  204.0  204.0  151.0   123    71   112  111   71
# 4          Донецька  271.0  214.0  140.0   109    61    98   82    —

# %%
# P1 T2
table.shape
# Out:
# (28, 9)

# %%
# P1 T3
table_upd_1_replace = table.replace(to_replace= "—", value= np.nan)
table_upd_1_replace
# Out:
#                Регіон   1950   1960   1970  1990  2000  2012 2014 2019
# 0                Крим  230.0  206.0  160.0   130    73   126  NaN  NaN
# 1           Вінницька  224.0  192.0  142.0   124    84   112  109   76
# 2           Волинська  247.0  250.0  179.0   153   112   148  141  101
# 3    Дніпропетровська  204.0  204.0  151.0   123    71   112  111   71
# 4            Донецька  271.0  214.0  140.0   109    61    98   82  NaN
# 5         Житомирська  261.0  223.0  159.0   129    89   122  120   79
# 6        Закарпатська  314.0  273.0  207.0   168   115   151  146  104
# 7          Запорізька  219.0  197.0  150.0   124    71   106  106   68
# 8   Івано-Франківська  243.0  248.0  182.0   155   103   124  122   88
# 9            Київська  204.0  189.0  156.0   123    73   122  121   80
# 10     Кіровоградська  216.0  171.0  145.0   126    79   110  108   68
# 11          Луганська  262.0  235.0  144.0   116    62    96   51  NaN
# 12          Львівська  234.0  240.0  171.0   140    91   119  119   87
# 13       Миколаївська  211.0  194.0  155.0   137    80   115  112   71
# 14            Одеська  241.0  192.0  148.0   126    80   127  123   88
# 15         Полтавська  186.0  163.0  131.0   118    70    99  100   65
# 16         Рівненська  269.0  267.0  193.0   158   118   159  148  107
# 17            Сумська  216.0  184.0  132.0   115    70    97   92   60
# 18      Тернопільська  213.0  216.0  157.0   142    92   113  109   76
# 19         Харківська  197.0  173.0  140.0   114    68    99  101   68
# 20         Херсонська  208.0  214.0  166.0   143    85   117  115   81
# 21        Хмельницька  234.0  198.0  148.0   129    85   113  112   79
# 22          Черкаська  205.0  179.0  144.0   123    75   100   98   64
# 23        Чернівецька  247.0  218.0  170.0   148   101   128  129   92
# 24       Чернігівська  220.0  183.0  127.0   108    69    94   90   61
# 25               Київ    NaN  174.0  159.0   120    73   120  121  110
# 26        Севастополь    NaN    NaN    NaN   125    70   120  NaN  NaN
# 27            Україна  228.0  205.0  152.0   126    78   114  111   81

# %%
# P1 T4
table_upd_1_replace.dtypes
# Out:
# Регіон     object
# 1950      float64
# 1960      float64
# 1970      float64
# 1990        int64
# 2000        int64
# 2012        int64
# 2014       object
# 2019       object
# dtype: object

# %%
# P1 T5
table_upd_1_replace["2014"] = pd.to_numeric(table_upd_1_replace["2014"])
table_upd_1_replace["2019"] = pd.to_numeric(table_upd_1_replace["2019"])
table_upd_1_replace.dtypes
# Out:
# Регіон     object
# 1950      float64
# 1960      float64
# 1970      float64
# 1990        int64
# 2000        int64
# 2012        int64
# 2014      float64
# 2019      float64
# dtype: object

# %%
# P1 T6
table_upd_1_replace.isnull().sum()/table_upd_1_replace.shape[0]
# table_upd_1_replace.sum()
# Out:
# Регіон    0.000000
# 1950      0.071429
# 1960      0.035714
# 1970      0.035714
# 1990      0.000000
# 2000      0.000000
# 2012      0.000000
# 2014      0.071429
# 2019      0.142857
# dtype: float64

# %%
# P1 T7
table_upd_2_del_row_total = table_upd_1_replace.drop([27])
table_upd_2_del_row_total
# Out:
#                Регіон   1950   1960   1970  1990  2000  2012   2014   2019
# 0                Крим  230.0  206.0  160.0   130    73   126    NaN    NaN
# 1           Вінницька  224.0  192.0  142.0   124    84   112  109.0   76.0
# 2           Волинська  247.0  250.0  179.0   153   112   148  141.0  101.0
# 3    Дніпропетровська  204.0  204.0  151.0   123    71   112  111.0   71.0
# 4            Донецька  271.0  214.0  140.0   109    61    98   82.0    NaN
# 5         Житомирська  261.0  223.0  159.0   129    89   122  120.0   79.0
# 6        Закарпатська  314.0  273.0  207.0   168   115   151  146.0  104.0
# 7          Запорізька  219.0  197.0  150.0   124    71   106  106.0   68.0
# 8   Івано-Франківська  243.0  248.0  182.0   155   103   124  122.0   88.0
# 9            Київська  204.0  189.0  156.0   123    73   122  121.0   80.0
# 10     Кіровоградська  216.0  171.0  145.0   126    79   110  108.0   68.0
# 11          Луганська  262.0  235.0  144.0   116    62    96   51.0    NaN
# 12          Львівська  234.0  240.0  171.0   140    91   119  119.0   87.0
# 13       Миколаївська  211.0  194.0  155.0   137    80   115  112.0   71.0
# 14            Одеська  241.0  192.0  148.0   126    80   127  123.0   88.0
# 15         Полтавська  186.0  163.0  131.0   118    70    99  100.0   65.0
# 16         Рівненська  269.0  267.0  193.0   158   118   159  148.0  107.0
# 17            Сумська  216.0  184.0  132.0   115    70    97   92.0   60.0
# 18      Тернопільська  213.0  216.0  157.0   142    92   113  109.0   76.0
# 19         Харківська  197.0  173.0  140.0   114    68    99  101.0   68.0
# 20         Херсонська  208.0  214.0  166.0   143    85   117  115.0   81.0
# 21        Хмельницька  234.0  198.0  148.0   129    85   113  112.0   79.0
# 22          Черкаська  205.0  179.0  144.0   123    75   100   98.0   64.0
# 23        Чернівецька  247.0  218.0  170.0   148   101   128  129.0   92.0
# 24       Чернігівська  220.0  183.0  127.0   108    69    94   90.0   61.0
# 25               Київ    NaN  174.0  159.0   120    73   120  121.0  110.0
# 26        Севастополь    NaN    NaN    NaN   125    70   120    NaN    NaN

# %%
# P1 T8
# val_1950 = table_upd_2_del_row_total["1950"].mean().round(1)
# val_1950
# val_1960 = table_upd_2_del_row_total["1960"].mean().round(1)
# val_1960
# val_1970 = table_upd_2_del_row_total["1970"].mean().round(1)
# val_1970
# val_1990 = table_upd_2_del_row_total["1990"].mean().round(1)
# val_1990
# val_2000 = table_upd_2_del_row_total["2000"].mean().round(1)
# val_2000
# val_2012 = table_upd_2_del_row_total["2012"].mean().round(1)
# val_2012
# val_2014 = table_upd_2_del_row_total["2014"].mean().round(1)
# val_2014
# val_2019 = table_upd_2_del_row_total["2019"].mean().round(1)
# val_2019

values = {"1950": table_upd_2_del_row_total["1950"].mean().round(1),
          "1960": table_upd_2_del_row_total["1960"].mean().round(1),
          "1970": table_upd_2_del_row_total["1970"].mean().round(1),
          "1990": table_upd_2_del_row_total["1990"].mean().round(1),
          "2000": table_upd_2_del_row_total["2000"].mean().round(1),
          "2012": table_upd_2_del_row_total["2012"].mean().round(1),
          "2014": table_upd_2_del_row_total["2014"].mean().round(1),
          "2019": table_upd_2_del_row_total["2019"].mean().round(1),
         }
table_upd_3_fillna_nan_to_average = table_upd_2_del_row_total.fillna(value=values)
table_upd_3_fillna_nan_to_average
# Out:
#                Регіон   1950   1960   1970  1990  2000  2012   2014   2019
# 0                Крим  230.0  206.0  160.0   130    73   126  111.4   80.2
# 1           Вінницька  224.0  192.0  142.0   124    84   112  109.0   76.0
# 2           Волинська  247.0  250.0  179.0   153   112   148  141.0  101.0
# 3    Дніпропетровська  204.0  204.0  151.0   123    71   112  111.0   71.0
# 4            Донецька  271.0  214.0  140.0   109    61    98   82.0   80.2
# 5         Житомирська  261.0  223.0  159.0   129    89   122  120.0   79.0
# 6        Закарпатська  314.0  273.0  207.0   168   115   151  146.0  104.0
# 7          Запорізька  219.0  197.0  150.0   124    71   106  106.0   68.0
# 8   Івано-Франківська  243.0  248.0  182.0   155   103   124  122.0   88.0
# 9            Київська  204.0  189.0  156.0   123    73   122  121.0   80.0
# 10     Кіровоградська  216.0  171.0  145.0   126    79   110  108.0   68.0
# 11          Луганська  262.0  235.0  144.0   116    62    96   51.0   80.2
# 12          Львівська  234.0  240.0  171.0   140    91   119  119.0   87.0
# 13       Миколаївська  211.0  194.0  155.0   137    80   115  112.0   71.0
# 14            Одеська  241.0  192.0  148.0   126    80   127  123.0   88.0
# 15         Полтавська  186.0  163.0  131.0   118    70    99  100.0   65.0
# 16         Рівненська  269.0  267.0  193.0   158   118   159  148.0  107.0
# 17            Сумська  216.0  184.0  132.0   115    70    97   92.0   60.0
# 18      Тернопільська  213.0  216.0  157.0   142    92   113  109.0   76.0
# 19         Харківська  197.0  173.0  140.0   114    68    99  101.0   68.0
# 20         Херсонська  208.0  214.0  166.0   143    85   117  115.0   81.0
# 21        Хмельницька  234.0  198.0  148.0   129    85   113  112.0   79.0
# 22          Черкаська  205.0  179.0  144.0   123    75   100   98.0   64.0
# 23        Чернівецька  247.0  218.0  170.0   148   101   128  129.0   92.0
# 24       Чернігівська  220.0  183.0  127.0   108    69    94   90.0   61.0
# 25               Київ  231.0  174.0  159.0   120    73   120  121.0  110.0
# 26        Севастополь  231.0  207.6  156.0   125    70   120  111.4   80.2

# %%
# P1 T9
avr_val2019 = table_upd_3_fillna_nan_to_average["2019"].mean().round(1)
# avr_val2019 # = 80.2
table_upd_3_fillna_nan_to_average[table_upd_3_fillna_nan_to_average["2019"] > avr_val2019][["Регіон", "2019"]]
# Out:
#                Регіон   2019
# 2           Волинська  101.0
# 6        Закарпатська  104.0
# 8   Івано-Франківська   88.0
# 12          Львівська   87.0
# 14            Одеська   88.0
# 16         Рівненська  107.0
# 20         Херсонська   81.0
# 23        Чернівецька   92.0
# 25               Київ  110.0

# %%
# P1 T10
table_upd_4_sort_by_max_value = table_upd_3_fillna_nan_to_average.sort_values(["2014"], ascending=False)[["Регіон", "2014"]].head(1)
table_upd_4_sort_by_max_value
# Out:
#         Регіон   2014
# 16  Рівненська  148.0

# %%
# P1 T11
graph = table_upd_3_fillna_nan_to_average.plot.bar(x="Регіон",
                                                   y="2019",
                                                   title = "Діаграма коефіцієнтів народжуваності в регіонах України у 2019 році",
                                                   ylabel = "Коефіцієнт",
                                                   figsize=(16, 10),
                                                   grid=True
                                                  )
graph
# Out:
# <Axes: title={'center': 'Діаграма коефіцієнтів народжуваності в регіонах України у 2019 році'}, xlabel='Регіон', ylabel='Коефіцієнт'>
